# %% [markdown]
# # IBL Data Tutorial

# %% [markdown]
# A tutorial for access and analysis of IBL data via the ONE API.

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Imports

# %%
import random
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from brainbox.io.one import SpikeSortingLoader
from brainbox.io.spikeglx import Streamer
from ibldsp.voltage import destripe, destripe_lfp
from iblutil.util import Bunch
from one.alf.io import AlfBunch
from one.api import OneAlyx, ONE  # Docs: https://int-brain-lab.github.io/ONE/

from src.utils import wd

# %% [markdown]
# ### Helper Class, etc.

# %% [markdown]
# IBL provides an api for access to all their data:

# %%
working_dir: Path = wd()

one_alyx: OneAlyx = ONE(
    cache_dir=working_dir / "cache" / "one",  # any directory where temporary files can be synced
    base_url="https://openalyx.internationalbrainlab.org",  # base url for the API
    password="international",  # public-access password
    silent=True,  # don't print progress, etc.
)  # most 'type: ignore' are because IBL's libraries are less strict on types # type: ignore

# %% [markdown]
# IBL has collected data from >450 experiments with >100 mice. Each in each experiment (session), mice are given behavioral tests while 1-2 Neuropixels probes record extracellular potentials associated with up to hundreds of neurons. Data are organized by session and probe insertion, with a 1-to-many relationship between session and insertion. Accessible data is associated with the session (e.g., behavior) or an insertion (e.g., neural activity). This is detailed in the most recent data release [1](https://figshare.com/articles/preprint/Data_release_-_Brainwide_map_-_Q4_2022/21400815?file=49286065).

# %%
data_tag = "2024_Q2_IBL_et_al_BWM_iblsort"  # tag for most recent data release ()
all_sessions: list = one_alyx.search(  # list of sessions
    tag=data_tag, query_type="remote"
)  # type: ignore
n_sessions = len(all_sessions)
print(f"Session count: {n_sessions}")
print(f"Session example: {all_sessions[0]}")

all_insertions: list = one_alyx.search_insertions(  # list of insertions
    tag=data_tag, query_type="remote"
)  # type: ignore
n_insertions = len(all_insertions)
print(f"Insertion count: {n_insertions}")
print(f"Insertion example: {all_insertions[0]}")
# Out:
# Session count: 459
# Session example: ebce500b-c530-47de-8cb1-963c552703ea
# Insertion count: 699
# Insertion example: 8c732bf2-639d-496c-bf82-464bc9c2d54b

# %% [markdown]
# ## Choose an insertion to explore

# %%
# We could randomly select a probe/insertion for data exploration
i = random.randint(0, (n_insertions - 1))
pid = str(all_insertions[i])
# However, we'll use the same one for consistency
pid_i = 534

# get the experimental session id and probe/insertion name
pid: str = str(all_insertions[pid_i])
pid_details: tuple[str, str] = one_alyx.pid2eid(pid)
eid, p_name = pid_details

print(f"Probe ID: {pid}")
print(f"Probe Name: {p_name}")
print(f"Experiment ID: {eid}")
# Out:
# Probe ID: 695476f6-4c14-4a2f-b658-948514629079
# Probe Name: probe00
# Experiment ID: 4720c98a-a305-4fba-affb-bbfa00a724a4

# %% [markdown]
# ## Stream and visualize recorded data

# %% [markdown]
# ### Streamer

# %% [markdown]
# Electrophysiology probes (Neuropixels) complete initial signal processing on-device, providing voltages associated with action potentials (AP) and local field potentials (LFP/LF) at each recording site (channel) over time at a specified frequency [[2](https://doi.org/10.1038/nature24636), [3](https://doi.org/10.1126/science.abf4588)]. This gives 10's of gigabytes per experiment in raw electrophysiology data, which can be streamed as follows.

# %%
ap_streamer = Streamer(pid=pid, one=one_alyx, remove_cached=False, typ="ap")
lf_streamer = Streamer(pid=pid, one=one_alyx, remove_cached=False, typ="lf")
# Out:
# (S3) /Users/wesley/GitHub/JWB/python-lfads/cache/one/danlab/Subjects/DY_014/2020-07-14/001/raw_ephys_data/probe00/_spikeglx_ephysData_g0_t0.imec0.ap.ch: 100%|██████████| 136k/136k [00:00<00:00, 381kB/s]
# (S3) /Users/wesley/GitHub/JWB/python-lfads/cache/one/danlab/Subjects/DY_014/2020-07-14/001/raw_ephys_data/probe00/_spikeglx_ephysData_g0_t0.imec0.ap.meta: 100%|██████████| 17.7k/17.7k [00:00<00:00, 115kB/s]
# (S3) /Users/wesley/GitHub/JWB/python-lfads/cache/one/danlab/Subjects/DY_014/2020-07-14/001/raw_ephys_data/probe00/_spikeglx_ephysData_g0_t0.imec0.lf.ch: 100%|██████████| 126k/126k [00:00<00:00, 389kB/s]
# (S3) /Users/wesley/GitHub/JWB/python-lfads/cache/one/danlab/Subjects/DY_014/2020-07-14/001/raw_ephys_data/probe00/_spikeglx_ephysData_g0_t0.imec0.lf.meta: 100%|██████████| 13.9k/13.9k [00:00<00:00, 79.8kB/s]
# 2026-01-08 11:04:46 WARNING  spikeglx.py:699  Meta data doesn't have geometry (snsShankMap/snsGeomMap field), returning defaults

# %% [markdown]
# ### Timeframe

# %%
start_time = 150  # seconds since beginning the electrophysiology recording
end_time = 152

ap_freq: int = int(ap_streamer.fs)  # ap sampling frequency # type: ignore
lf_freq: int = int(lf_streamer.fs)  # lf sampling frequency # type: ignore

start_ap: int = int(start_time) * int(ap_freq)
end_ap: int = int(end_time) * int(ap_freq)
start_lf: int = int(start_time) * int(lf_freq)
end_lf: int = int(end_time) * int(lf_freq)

# %% [markdown]
# ### Raw Data

# %%
ap_timeframe_data: np.ndarray = ap_streamer[start_ap:end_ap]  # type: ignore
lf_timeframe_data: np.ndarray = lf_streamer[start_lf:end_lf]  # type: ignore

print(
    f"We have numpy matrices for the AP voltage data with shape {ap_timeframe_data.shape} and for the LF voltage data with shape {lf_timeframe_data.shape}"
)
# Out:
# 2026-01-08 11:04:50 WARNING  spikeglx.py:699  Meta data doesn't have geometry (snsShankMap/snsGeomMap field), returning defaults
# We have numpy matrices for the AP voltage data with shape (60000, 385) and for the LF voltage data with shape (5000, 385)

# %% [markdown]
# ### Denoised Data

# %% [markdown]
# Initial measurements include sync channels for handling timing [[3](https://doi.org/10.1126/science.abf4588)]. These can be removed, and the raw data can be cleaned with a denoising algorithm.

# %%
# remove sync channels
n_sync_channels_ap = int(ap_streamer.nsync)
n_sync_channels_lf = int(lf_streamer.nsync)
ap_timeframe_data = ap_timeframe_data[:, :-n_sync_channels_ap]
lf_timeframe_data = lf_timeframe_data[:, :-n_sync_channels_lf]

# transpose for the denoising algorithm
ap_timeframe_data = ap_timeframe_data.T
lf_timeframe_data = lf_timeframe_data.T

# denoising
ap_timeframe_data = destripe(ap_timeframe_data, ap_freq)
lf_timeframe_data = destripe_lfp(lf_timeframe_data, lf_freq)

print(
    f"After removing sync channels and denoising, numpy matrices for the AP voltage data with shape {ap_timeframe_data.shape} and for the LF voltage data with shape {lf_timeframe_data.shape}"
)
# Out:
# After removing sync channels and denoising, numpy matrices for the AP voltage data with shape (384, 60000) and for the LF voltage data with shape (384, 5000)

# %% [markdown]
# ### Matrix Values

# %%
print(
    f"AP values range from {float(ap_timeframe_data.min())} volts to {float(ap_timeframe_data.max())} volts"
)
print(
    f"LF values range from {float(lf_timeframe_data.min())} volts to {float(lf_timeframe_data.max())} volts"
)
# Out:
# AP values range from -0.0007157887607786226 volts to 0.0004466027778189911 volts
# LF values range from -0.00027276308442640275 volts to 0.0001646239446927148 volts

# %% [markdown]
# ### Plot Unclustered Voltage Data

# %%
fig, axs = plt.subplots(2, 1, figsize=(15, 10), sharex=True, sharey=True)

pcm1 = axs[0].pcolormesh(
    np.arange(start_time, end_time, ((end_time - start_time) / ap_timeframe_data.shape[1])),
    np.arange(0, (ap_timeframe_data.shape[0])),
    ap_timeframe_data,
    shading="auto",
    cmap="coolwarm",
    vmin=-0.00001,
    vmax=0.00001,
)
axs[0].set_title("AP Band")
axs[0].set_ylabel("Channel")

pcm2 = axs[1].pcolormesh(
    np.arange(start_time, end_time, ((end_time - start_time) / lf_timeframe_data.shape[1])),
    np.arange(0, (lf_timeframe_data.shape[0])),
    lf_timeframe_data,
    shading="auto",
    cmap="coolwarm",
    vmin=-0.00001,
    vmax=0.00001,
)
axs[1].set_title("LF Band")
axs[1].set_xlabel("Time (s)")
axs[1].set_ylabel("Channel")

fig.colorbar(pcm1, ax=axs, orientation="vertical", label="Voltage (Volts)")

# %% [markdown]
# ### Brief Discussion

# %% [markdown]
# The AP band provided by the Neuropixels device represents short-wavelength signals putatively resulting from action potentials. The LF band represents long-wavelength signals putatively resulting from all activity in the local environment, including the influence of the many cells far enough from the probe that their action potentials cannot be identified. These signals alone can be input directly into machine learning algorithms to make predictions about associations with expressed or desired behavior [[4](https://doi.org/10.2196/16194)]. However, this site-specific data does not differentiate the activity of individual cells.
#
# The problem of differentiating the activity of individual cells at this scale is relatively new. Neuropixels and related devices have only been developed during the last decade, and have increased bandwidth of data collection by combining volume coverage with spatial and temporal resolution [[2](https://doi.org/10.1038/nature24636), [3](https://doi.org/10.1126/science.abf4588), [4](https://doi.org/10.2196/16194)]. These hardware developments have led to a need for data pipelines that identify individual spikes and assign them to groups associated with putative neurons. One algorithm, KiloSort, accomplishes this through the following high-level steps: (1) divide the matrix of voltages and channels into sub-matrices with single spikes that could correspond to an action potential, (2) split spikes that likely correspond to an overlap of multiple action potentials, and (3) assign each spike to cluster associated with a putative neuron [[5](https://doi.org/10.1038/s41592-024-02232-7), [6](https://proceedings.neurips.cc/paper_files/paper/2016/file/1145a30ff80745b56fb0cecf65305017-Paper.pdf)]. As KiloSort has already been implemented on this data [[7](https://doi.org/10.6084/m9.figshare.19705522.v4)], the next section will demonstrate how to access and use the spike-sorted data.

# %% [markdown]
# ## Load and Visualize Spike-Sorted Data

# %% [markdown]
# ### Spike Loader

# %% [markdown]
# As with the raw data streamer, IBL provides a class to access spike data.

# %%
spike_loader = SpikeSortingLoader(pid=pid, one=one_alyx)

# %% [markdown]
# ### Load Spike Data

# %% [markdown]
# Spike data for an insertion is held by the IBL in three tables: spikes, clusters, and channels.
#
# IBL uses custom data types that are flexible subclasses of dicts to hold the data tables: `Bunch` and `AlfBunch`.

# %%
spike_sorting_data: tuple[AlfBunch, AlfBunch, Bunch] = spike_loader.load_spike_sorting()  # type: ignore
spikes, clusters, channels = spike_sorting_data
# Out:
# (S3) /Users/wesley/GitHub/JWB/python-lfads/cache/one/danlab/Subjects/DY_014/2020-07-14/001/alf/probe00/pykilosort/#2024-05-06#/spikes.amps.npy: 100%|██████████| 220M/220M [00:24<00:00, 8.92MB/s]
# (S3) /Users/wesley/GitHub/JWB/python-lfads/cache/one/danlab/Subjects/DY_014/2020-07-14/001/alf/probe00/pykilosort/#2024-05-06#/spikes.clusters.npy: 100%|██████████| 110M/110M [00:14<00:00, 7.36MB/s]
# (S3) /Users/wesley/GitHub/JWB/python-lfads/cache/one/danlab/Subjects/DY_014/2020-07-14/001/alf/probe00/pykilosort/#2024-05-06#/spikes.depths.npy: 100%|██████████| 220M/220M [00:27<00:00, 8.05MB/s]
# (S3) /Users/wesley/GitHub/JWB/python-lfads/cache/one/danlab/Subjects/DY_014/2020-07-14/001/alf/probe00/pykilosort/#2024-05-06#/spikes.times.npy: 100%|██████████| 220M/220M [00:28<00:00, 7.83MB/s]
# (S3) /Users/wesley/GitHub/JWB/python-lfads/cache/one/danlab/Subjects/DY_014/2020-07-14/001/alf/probe00/pykilosort/#2024-05-06#/clusters.channels.npy: 100%|██████████| 4.98k/4.98k [00:00<00:00, 29.4kB/s]
# (S3) /Users/wesley/GitHub/JWB/python-lfads/cache/one/danlab/Subjects/DY_014/2020-07-14/001/alf/probe00/pykilosort/#2024-05-06#/clusters.depths.npy: 100%|██████████| 2.55k/2.55k [00:00<00:00, 16.4kB/s]
# (S3) /Users/wesley/GitHub/JWB/python-lfads/cache/one/danlab/Subjects/DY_014/2020-07-14/001/alf/probe00/pykilosort/#2024-05-06#/clusters.metrics.pqt: 100%|██████████| 87.8k/87.8k [00:00<00:00, 230kB/s]
# (S3) /Users/wesley/GitHub/JWB/python-lfads/cache/one/danlab/Subjects/DY_014/2020-07-14/001/alf/probe00/pykilosort/#2024-05-06#/clusters.uuids.csv: 100%|██████████| 22.4k/22.4k [00:00<00:00, 131kB/s]
# (S3) /Users/wesley/GitHub/JWB/python-lfads/cache/one/danlab/Subjects/DY_014/2020-07-14/001/alf/probe00/pykilosort/#2024-05-06#/channels.brainLocationIds_ccf_2017.npy: 100%|██████████| 3.20k/3.20k [00:00<00:00, 12.1kB/s]
# (S3) /Users/wesley/GitHub/JWB/python-lfads/cache/one/danlab/Subjects/DY_014/2020-07-14/001/alf/probe00/pykilosort/#2024-05-06#/channels.labels.npy: 100%|██████████| 512/512 [00:00<00:00, 3.18kB/s]
# (S3) /Users/wesley/GitHub/JWB/python-lfads/cache/one/danlab/Subjects/DY_014/2020-07-14/001/alf/probe00/pykilosort/#2024-05-06#/channels.localCoordinates.npy: 100%|██████████| 3.20k/3.20k [00:00<00:00, 15.5kB/s]
# (S3) /Users/wesley/GitHub/JWB/python-lfads/cache/one/danlab/Subjects/DY_014/2020-07-14/001/alf/probe00/pykilosort/#2024-05-06#/channels.mlapdv.npy: 100%|██████████| 4.74k/4.74k [00:00<00:00, 29.4kB/s]
# (S3) /Users/wesley/GitHub/JWB/python-lfads/cache/one/danlab/Subjects/DY_014/2020-07-14/001/alf/probe00/pykilosort/#2024-05-06#/channels.rawInd.npy: 100%|██████████| 3.20k/3.20k [00:00<00:00, 18.5kB/s]
# (S3) /Users/wesley/GitHub/JWB/python-lfads/cache/one/danlab/Subjects/DY_014/2020-07-14/001/alf/probe00/electrodeSites.mlapdv.npy: 100%|██████████| 4.74k/4.74k [00:00<00:00, 27.5kB/s]
# (S3) /Users/wesley/GitHub/JWB/python-lfads/cache/one/danlab/Subjects/DY_014/2020-07-14/001/alf/probe00/electrodeSites.localCoordinates.npy: 100%|██████████| 3.20k/3.20k [00:00<00:00, 18.7kB/s]
# (S3) /Users/wesley/GitHub/JWB/python-lfads/cache/one/danlab/Subjects/DY_014/2020-07-14/001/alf/probe00/electrodeSites.brainLocationIds_ccf_2017.npy: 100%|██████████| 3.20k/3.20k [00:00<00:00, 14.9kB/s]

# %% [markdown]
# ### Spikes

# %% [markdown]
# The spikes table holds a list of all spikes identified and their associated time, voltage, and cluster.

# %%
spikes_df = spikes.to_df()
spikes_df
# Out:
#               amps  clusters       depths        times
# 0         0.000058       512  3413.953125     0.000685
# 1         0.000077       248   522.224609     0.000818
# 2         0.000078        89   194.612640     0.000985
# 3         0.000046       314   877.903320     0.001552
# 4         0.000067       556   755.919312     0.001552
# ...            ...       ...          ...          ...
# 27478045  0.000072       287   718.712646  4387.386601
# 27478046  0.000089       320   859.444580  4387.387934
# 27478047  0.000050       441  2887.549316  4387.388301
# 27478048  0.000074       287   714.392090  4387.388468
# 27478049  0.000138       551   673.484131  4387.388868
#
# [27478050 rows x 4 columns]

# %% [markdown]
# ### Clusters

# %% [markdown]
# The clusters table holds a list of clusters identified and associated metadata including a unique identifier, average voltage assigned to the cluster, and recording channels associated with the cluster. The clusters `AlfBunch` includes a dataframe nested in one of its columns, so we do some wrangling to make a flat 2D data table.

# %%
clusters_wrangled: dict = {}
for k, v in clusters.items():
    if v.ndim == 1:
        clusters_wrangled[k] = v
    elif v.ndim == 2:
        for k_sub in v:
            v_sub = v[k_sub]
            clusters_wrangled[k_sub] = v_sub
    else:
        raise ValueError("Bad dimensions")


clusters_df: pd.DataFrame = pd.DataFrame(clusters_wrangled)
clusters_df
# Out:
#      channels  depths  cluster_id   amp_max   amp_min  amp_median  amp_std_dB  \
# 0           0    20.0           0  0.000239  0.000066    0.000128    1.202803
# 1           0    20.0           1  0.000101  0.000045    0.000052    1.373974
# 2           1    20.0           2  0.000230  0.000059    0.000080    1.968509
# 3           1    20.0           3  0.000168  0.000043    0.000051    1.583340
# 4           1    20.0           4  0.000088  0.000037    0.000042    1.177437
# ..        ...     ...         ...       ...       ...         ...         ...
# 601       349  3500.0         601  0.000052  0.000044    0.000047    0.454855
# 602       349  3500.0         602  0.000043  0.000032    0.000034    0.613128
# 603       350  3520.0         603  0.000116  0.000051    0.000057    1.019759
# 604       294  2960.0         604  0.000080  0.000033    0.000047    1.123559
# 605       349  3500.0         605  0.000049  0.000037    0.000040    0.633731
#
#      contamination  contamination_alt         drift  ...  spike_count  \
# 0         0.000614           0.000606  2.410610e+06  ...     208337.0
# 1         0.000000           0.000000  9.437402e+03  ...        333.0
# 2         0.426780           0.305181  1.334003e+06  ...      69774.0
# 3         0.762317           0.481094  8.565348e+05  ...      36072.0
# 4         2.055150           0.972173  1.356305e+05  ...       6707.0
# ..             ...                ...           ...  ...          ...
# 601       0.000000           0.000000  8.965200e+02  ...         45.0
# 602       0.000000           0.000000  7.628500e+02  ...         41.0
# 603       0.191065           0.160280  1.833755e+05  ...      13735.0
# 604       0.000000           0.000000  8.747828e+03  ...        860.0
# 605       0.000000           0.000000  6.545269e+02  ...         46.0
#
#      slidingRP_viol_forced  max_confidence  min_contamination  \
# 0                      0.0    1.000000e+02                0.5
# 1                      0.0    2.291341e+00                NaN
# 2                      0.0    7.156311e-06               17.0
# 3                      0.0    7.356894e-05               22.0
# 4                      0.0    6.957768e-11                NaN
# ..                     ...             ...                ...
# 601                    0.0    0.000000e+00                NaN
# 602                    0.0    1.998001e-01                NaN
# 603                    0.0    7.811478e+01               12.0
# 604                    0.0    5.542513e+01               28.5
# 605                    0.0    1.998001e-01                NaN
#
#      n_spikes_below2  firing_rate     label  bitwise_fail  ks2_label  \
# 0                 38    47.485427  1.000000             0       good
# 1                  0     0.075899  0.333333             3        mua
# 2               1969    15.903311  0.333333             3        mua
# 3               1194     8.221748  0.333333             3        mua
# 4                 87     1.528700  0.000000             7        mua
# ..               ...          ...       ...           ...        ...
# 601                0     0.010257  0.333333             5        mua
# 602                0     0.009345  0.333333             5        mua
# 603               52     3.130564  0.333333             3        mua
# 604                0     0.196016  0.333333             5       good
# 605                0     0.010485  0.333333             5        mua
#
#                                     uuids
# 0    2640eb9c-69b4-40db-ab8b-95ad386007da
# 1    6245d874-f12d-44a7-9e61-842b648fae9e
# 2    060ea9a4-5d33-486f-b53d-1562ced5304c
# 3    4980e5ab-1a1c-428c-b31a-76c901510593
# 4    26df70b8-00ac-4b77-bf99-63d280eb49e5
# ..                                    ...
# 601  348e2d5b-4a53-4b28-943b-85de4115dd03
# 602  ffba0605-08ad-40ce-8dfa-ee80deb8f10e
# 603  2ede8599-325e-491a-97a0-cbf9421a0ea4
# 604  790370fe-a46b-4e46-a13c-fe84ca8fb66b
# 605  969f4988-feff-4042-82a3-8c4723f8b5a8
#
# [606 rows x 25 columns]

# %% [markdown]
# ### Channels

# %% [markdown]
# The channels table holds the list of recording channels, and associated anatomical information associated with the Allen Mouse Brain Atlas.

# %%
channels_df = AlfBunch(channels).to_df()
channels_df
# Out:
#             x         y         z     acronym  atlas_id  axial_um  lateral_um  \
# 0   -0.001907 -0.001250 -0.004395         VPL       718      20.0        43.0
# 1   -0.001907 -0.001250 -0.004395         VPL       718      20.0        11.0
# 2   -0.001911 -0.001250 -0.004375         VPL       718      40.0        59.0
# 3   -0.001911 -0.001250 -0.004375         VPL       718      40.0        27.0
# 4   -0.001915 -0.001248 -0.004356         VPL       718      60.0        43.0
# ..        ...       ...       ...         ...       ...       ...         ...
# 379 -0.003074 -0.000558 -0.000952  SSp-bfd2/3       201    3800.0        27.0
# 380 -0.003081 -0.000556 -0.000934  SSp-bfd2/3       201    3820.0        43.0
# 381 -0.003081 -0.000556 -0.000934  SSp-bfd2/3       201    3820.0        11.0
# 382 -0.003087 -0.000555 -0.000915  SSp-bfd2/3       201    3840.0        59.0
# 383 -0.003087 -0.000555 -0.000915  SSp-bfd2/3       201    3840.0        27.0
#
#      labels  rawInd
# 0         0       0
# 1         0       1
# 2         0       2
# 3         0       3
# 4         0       4
# ..      ...     ...
# 379       0     379
# 380       0     380
# 381       0     381
# 382       0     382
# 383       0     383
#
# [384 rows x 9 columns]

# %% [markdown]
# ### Merged Clusters

# %% [markdown]
# Data can be joined between tables; for example, the `.merge_clusters` method merges data from spikes and channels to add attributes such as spike voltage statistics and anatomical location to the clusters table.

# %%
merged_clusters: AlfBunch = spike_loader.merge_clusters(spikes, clusters, channels)  # type: ignore

# %%
merged_clusters_df = merged_clusters.to_df()
merged_clusters_df
# Out:
#      channels  depths                                 uuids  cluster_id  \
# 0           0    20.0  2640eb9c-69b4-40db-ab8b-95ad386007da           0
# 1           0    20.0  6245d874-f12d-44a7-9e61-842b648fae9e           1
# 2           1    20.0  060ea9a4-5d33-486f-b53d-1562ced5304c           2
# 3           1    20.0  4980e5ab-1a1c-428c-b31a-76c901510593           3
# 4           1    20.0  26df70b8-00ac-4b77-bf99-63d280eb49e5           4
# ..        ...     ...                                   ...         ...
# 601       349  3500.0  348e2d5b-4a53-4b28-943b-85de4115dd03         601
# 602       349  3500.0  ffba0605-08ad-40ce-8dfa-ee80deb8f10e         602
# 603       350  3520.0  2ede8599-325e-491a-97a0-cbf9421a0ea4         603
# 604       294  2960.0  790370fe-a46b-4e46-a13c-fe84ca8fb66b         604
# 605       349  3500.0  969f4988-feff-4042-82a3-8c4723f8b5a8         605
#
#       amp_max   amp_min  amp_median  amp_std_dB  contamination  \
# 0    0.000239  0.000066    0.000128    1.202803       0.000614
# 1    0.000101  0.000045    0.000052    1.373974       0.000000
# 2    0.000230  0.000059    0.000080    1.968509       0.426780
# 3    0.000168  0.000043    0.000051    1.583340       0.762317
# 4    0.000088  0.000037    0.000042    1.177437       2.055150
# ..        ...       ...         ...         ...            ...
# 601  0.000052  0.000044    0.000047    0.454855       0.000000
# 602  0.000043  0.000032    0.000034    0.613128       0.000000
# 603  0.000116  0.000051    0.000057    1.019759       0.191065
# 604  0.000080  0.000033    0.000047    1.123559       0.000000
# 605  0.000049  0.000037    0.000040    0.633731       0.000000
#
#      contamination_alt  ...  ks2_label         x         y         z  \
# 0             0.000606  ...       good -0.001907 -0.001250 -0.004395
# 1             0.000000  ...        mua -0.001907 -0.001250 -0.004395
# 2             0.305181  ...        mua -0.001907 -0.001250 -0.004395
# 3             0.481094  ...        mua -0.001907 -0.001250 -0.004395
# 4             0.972173  ...        mua -0.001907 -0.001250 -0.004395
# ..                 ...  ...        ...       ...       ...       ...
# 601           0.000000  ...        mua -0.002976 -0.000579 -0.001235
# 602           0.000000  ...        mua -0.002976 -0.000579 -0.001235
# 603           0.160280  ...        mua -0.002983 -0.000578 -0.001216
# 604           0.000000  ...       good -0.002809 -0.000692 -0.001730
# 605           0.000000  ...        mua -0.002976 -0.000579 -0.001235
#
#        acronym  atlas_id  axial_um  lateral_um  labels  rawInd
# 0          VPL       718      20.0        43.0       0       0
# 1          VPL       718      20.0        43.0       0       0
# 2          VPL       718      20.0        11.0       0       1
# 3          VPL       718      20.0        11.0       0       1
# 4          VPL       718      20.0        11.0       0       1
# ..         ...       ...       ...         ...     ...     ...
# 601   SSp-bfd4      1047    3500.0        11.0       0     349
# 602   SSp-bfd4      1047    3500.0        11.0       0     349
# 603   SSp-bfd4      1047    3520.0        59.0       0     350
# 604  SSp-bfd6a      1038    2960.0        59.0       0     294
# 605   SSp-bfd4      1047    3500.0        11.0       0     349
#
# [606 rows x 34 columns]

# %% [markdown]
# ### Wrangle Spikes for Visualization

# %% [markdown]
# Trim the timeframe

# %%
spikes_df_timeframe = spikes_df[start_time <= spikes_df["times"]]
spikes_df_timeframe = spikes_df_timeframe[spikes_df_timeframe["times"] <= end_time]
spikes_df_timeframe
# Out:
#              amps  clusters       depths       times
# 1064505  0.000179       213   500.639526  150.000098
# 1064506  0.000068       287   792.859009  150.000198
# 1064507  0.000071        76   193.428528  150.000298
# 1064508  0.000028       374  1119.744629  150.000465
# 1064509  0.000173       190   459.618500  150.000598
# ...           ...       ...          ...         ...
# 1080372  0.000131       218   524.351562  151.999812
# 1080373  0.000071       180   407.717468  151.999812
# 1080374  0.000066       355  1000.125610  151.999846
# 1080375  0.000325       129   294.618591  151.999946
# 1080376  0.000058       315   881.051880  151.999946
#
# [15872 rows x 4 columns]

# %% [markdown]
# Create a new ID for clusters that is ordered by position along the probe, etc.

# %%
cluster_channel_map = (
    merged_clusters_df[["cluster_id", "channels"]]
    .copy()
    .sort_values(by="channels", ascending=True)
    .reset_index(drop=True)
    .reset_index(drop=False)
    .rename(inplace=False, columns={"index": "cluster_channel_id"})
)
cluster_channel_map
# Out:
#      cluster_channel_id  cluster_id  channels
# 0                     0           0         0
# 1                     1           1         0
# 2                     2           2         1
# 3                     3           3         1
# 4                     4           4         1
# ..                  ...         ...       ...
# 601                 601         538       367
# 602                 602         590       367
# 603                 603         592       367
# 604                 604         539       371
# 605                 605         540       383
#
# [606 rows x 3 columns]

# %% [markdown]
# Join new ID and channel assignment to spikes

# %%
us_per_s = 1000000
spikes_df_timeframe = spikes_df_timeframe.merge(
    cluster_channel_map, left_on="clusters", right_on="cluster_id", how="left"
)
spikes_df_timeframe
# Out:
#            amps  clusters       depths       times  cluster_channel_id  \
# 0      0.000179       213   500.639526  150.000098                 219
# 1      0.000068       287   792.859009  150.000198                 300
# 2      0.000071        76   193.428528  150.000298                  73
# 3      0.000028       374  1119.744629  150.000465                 396
# 4      0.000173       190   459.618500  150.000598                 195
# ...         ...       ...          ...         ...                 ...
# 15867  0.000131       218   524.351562  151.999812                 225
# 15868  0.000071       180   407.717468  151.999812                 187
# 15869  0.000066       355  1000.125610  151.999846                 376
# 15870  0.000325       129   294.618591  151.999946                 130
# 15871  0.000058       315   881.051880  151.999946                 335
#
#        cluster_id  channels
# 0             213        48
# 1             287        73
# 2              76        14
# 3             374       106
# 4             190        42
# ...           ...       ...
# 15867         218        49
# 15868         180        41
# 15869         355        98
# 15870         129        29
# 15871         315        84
#
# [15872 rows x 7 columns]

# %% [markdown]
# ### Two Seconds of Clustered Spikes

# %%
fig, axs = plt.subplots(figsize=(10, 8))

axs.scatter(
    spikes_df_timeframe["times"].values,  # type: ignore
    spikes_df_timeframe["cluster_channel_id"].values,  # type: ignore
    s=1,
    alpha=0.5,
    c="#000000",
    marker="s",
)

axs.set_title("Putative Neural Spikes")
axs.set_xlabel("Time (s)")
axs.set_ylabel("Putative Neuron")
# Out:
# Text(0, 0.5, 'Putative Neuron')

# %% [markdown]
# ### 0.1 Seconds of Clustered Spikes

# %%
fig, axs = plt.subplots(figsize=(10, 8))

axs.scatter(
    spikes_df_timeframe[spikes_df_timeframe["times"] <= 150.1]["times"].values,  # type: ignore
    spikes_df_timeframe[spikes_df_timeframe["times"] <= 150.1]["cluster_channel_id"].values,  # type: ignore
    s=1,
    alpha=0.5,
    c="#000000",
    marker="s",
)

axs.set_title("Putative Neural Spikes")
axs.set_xlabel("Time (s)")
axs.set_ylabel("Putative Neuron")
# Out:
# Text(0, 0.5, 'Putative Neuron')
